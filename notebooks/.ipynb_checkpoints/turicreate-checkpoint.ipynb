# %% [markdown]
# # Get data and packages

# %%
# !pip install -U pip
# !conda update -y --all
# !pip install --upgrade tensorflow==2.0.0-beta1
# !pip install --upgrade turicreate
# !aws s3 cp --recursive s3://xdss-public-datasets/demos/taxi_1m.sframe ../datasets/taxi_1m.sframe
# Out:
# Collecting pip
#   Downloading https://files.pythonhosted.org/packages/00/b6/9cfa56b4081ad13874b0c6f96af8ce16cfbc1cb06bedf8e9164ce5551ec1/pip-19.3.1-py2.py3-none-any.whl (1.4MB)
#     100% |████████████████████████████████| 1.4MB 21.5MB/s ta 0:00:01
# Installing collected packages: pip
#   Found existing installation: pip 10.0.1
#     Uninstalling pip-10.0.1:
#       Successfully uninstalled pip-10.0.1
# Successfully installed pip-19.3.1
# Solving environment: |
# Warning: 4 possible package resolutions (only showing differing packages):
#   - defaults::jupyter_console-6.0.0-py36_0, defaults::libgfortran-3.0.0-1, defaults::prompt_toolkit-2.0.10-py_0
#   - conda-forge::libgfortran-3.0.0-1, defaults::jupyter_console-6.0.0-py36_0, defaults::prompt_toolkit-2.0.10-py_0
#   - defaults::jupyter_console-5.2.0-py36_1, defaults::libgfortran-3.0.0-1, defaults::prompt_toolkit-3.0.2-py_0
#   - conda-forge::libgfortran-3.0.0-1, defaults::jupyter_console-5.2.0-py36_1, defaults::prompt_toolkit-3.0.2-pydone
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.12
#   latest version: 4.8.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     gmpy2-2.0.8                |   py36h10f8cd9_2         165 KB
#     pyrsistent-0.15.6          |   py36h7b6447c_0          93 KB
#     sphinxcontrib-applehelp-1.0.1|             py_0          29 KB
#     pluggy-0.13.1              |           py36_0          32 KB
#     astropy-3.2.3              |   py36h7b6447c_0         7.2 MB
#     contextlib2-0.6.0.post1    |             py_0          16 KB
#     pyparsing-2.4.5            |             py_0          62 KB
#     jsonschema-3.2.0           |           py36_0          93 KB
#     diff-match-patch-20181111  |             py_0          39 KB
#     pyodbc-4.0.27              |   py36he6710b0_0          70 KB
#     keyring-19.2.0             |           py36_0          56 KB
#     imageio-2.6.1              |           py36_0         3.4 MB
#     jupyterlab_server-1.0.6    |             py_0          26 KB
#     backports.shutil_get_terminal_size-1.0.0|           py36_2           8 KB
#     libprotobuf-3.11.2         |       hd408876_0         4.8 MB
#     mpi-1.0                    |          openmpi           6 KB
#     intel-openmp-2019.4        |              243         876 KB
#     json5-0.8.5                |             py_0          25 KB
#     lazy-object-proxy-1.4.3    |   py36h7b6447c_0          31 KB
#     watchdog-0.9.0             |           py36_1          93 KB
#     clyent-1.2.2               |           py36_1          18 KB
#     cycler-0.10.0              |           py36_0          13 KB
#     gevent-1.4.0               |   py36h7b6447c_0         2.5 MB
#     testpath-0.4.4             |             py_0          88 KB
#     ujson-1.35                 |   py36h14c3975_0          26 KB
#     pyopenssl-19.1.0           |           py36_0          87 KB
#     fsspec-0.6.2               |             py_0          50 KB
#     jupyterlab_launcher-0.13.1 |           py36_0          36 KB
#     giflib-5.1.4               |       h14c3975_1          78 KB
#     isort-4.3.21               |           py36_0          68 KB
#     nose-1.3.7                 |           py36_2         214 KB
#     lxml-4.4.2                 |   py36hefd8a0e_0         1.6 MB
#     dask-2.9.0                 |             py_0          12 KB
#     qdarkstyle-2.7             |             py_0         728 KB
#     werkzeug-0.16.0            |             py_0         255 KB
#     protobuf-3.11.2            |   py36he6710b0_0         708 KB
#     more-itertools-8.0.2       |             py_0          37 KB
#     joblib-0.14.1              |             py_0         202 KB
#     sphinxcontrib-websupport-1.1.2|             py_0          35 KB
#     libglu-9.0.0               |       hf484d3e_1         377 KB
#     statsmodels-0.10.1         |   py36hdd07704_0         9.6 MB
#     alabaster-0.7.12           |             py_0          16 KB
#     spyder-4.0.0               |           py36_0         7.7 MB
#     sqlalchemy-1.3.11          |   py36h7b6447c_0         1.8 MB
#     numpy-base-1.17.4          |   py36hde5b4d6_0         5.3 MB
#     bkcharts-0.2               |           py36_0         127 KB
#     openmpi-4.0.2              |       hb1b8bf9_1         3.9 MB
#     pympler-0.7                |             py_0         159 KB
#     singledispatch-3.4.0.3     |           py36_0          15 KB
#     pytz-2019.3                |             py_0         231 KB
#     xlwt-1.3.0                 |           py36_0         163 KB
#     ipython-7.10.2             |   py36h39e3cac_0         1.1 MB
#     notebook-6.0.2             |           py36_0         6.3 MB
#     pytest-astropy-0.7.0       |             py_0           9 KB
#     sphinxcontrib-qthelp-1.0.2 |             py_0          26 KB
#     networkx-2.4               |             py_0         1.2 MB
#     datashape-0.5.4            |           py36_1         100 KB
#     scikit-learn-0.22          |   py36hd81dba3_0         7.1 MB
#     matplotlib-3.1.1           |   py36h5429711_0         6.7 MB
#     anaconda-client-1.7.2      |           py36_0         141 KB
#     pyflakes-2.1.1             |           py36_0         105 KB
#     sphinxcontrib-1.0          |           py36_1           3 KB
#     jupyterlab-1.2.4           |     pyhf63ae98_0         5.0 MB
#     pyxdg-0.26                 |             py_0          46 KB
#     pycodestyle-2.5.0          |           py36_0          60 KB
#     psutil-5.6.7               |   py36h7b6447c_0         328 KB
#     heapdict-1.0.1             |             py_0           9 KB
#     olefile-0.46               |             py_0          33 KB
#     mkl_fft-1.0.15             |   py36ha843d7b_0         173 KB
#     pycrypto-2.6.1             |   py36h14c3975_9         465 KB
#     sympy-1.5                  |           py36_0        10.3 MB
#     typed-ast-1.4.0            |   py36h7b6447c_0         208 KB
#     spyder-kernels-1.8.1       |           py36_0          90 KB
#     hypothesis-4.54.2          |           py36_0         407 KB
#     libiconv-1.15              |       h63c8f33_5         2.0 MB
#     qtpy-1.9.0                 |             py_0          39 KB
#     libopenblas-0.3.6          |       h5a2b251_2         7.7 MB
#     partd-1.1.0                |             py_0          20 KB
#     sortedcontainers-2.1.0     |           py36_0          45 KB
#     importlib_metadata-1.3.0   |           py36_0          46 KB
#     unicodecsv-0.14.1          |           py36_0          25 KB
#     libspatialindex-1.9.3      |       he6710b0_0         3.1 MB
#     pycurl-7.43.0.3            |   py36h1ba5d50_0          70 KB
#     mpc-1.1.0                  |       h10f8cd9_1          94 KB
#     botocore-1.13.39           |             py_0         3.6 MB
#     boto3-1.10.39              |             py_0          93 KB
#     pytest-doctestplus-0.5.0   |             py_0          21 KB
#     ffmpeg-4.0                 |       hcdf2ecd_0        73.7 MB
#     libopus-1.3                |       h7b6447c_0         631 KB
#     sphinxcontrib-htmlhelp-1.0.2|             py_0          28 KB
#     seaborn-0.9.0              |     pyh91ea838_1         164 KB
#     bottleneck-1.3.1           |   py36hdd07704_0         136 KB
#     future-0.18.2              |           py36_0         721 KB
#     pytest-remotedata-0.3.2    |           py36_0          15 KB
#     unixodbc-2.3.7             |       h14c3975_0         319 KB
#     toolz-0.10.0               |             py_0          50 KB
#     distributed-2.9.0          |             py_0         401 KB
#     multipledispatch-0.6.0     |           py36_0          21 KB
#     sphinxcontrib-devhelp-1.0.1|             py_0          23 KB
#     libwebp-1.0.1              |       h8e7db2f_0         913 KB
#     path.py-12.4.0             |                0           7 KB
#     flask-cors-3.0.8           |             py_0          17 KB
#     pylint-2.4.4               |           py36_0         434 KB
#     jedi-0.14.1                |           py36_0         711 KB
#     kiwisolver-1.1.0           |   py36he6710b0_0          90 KB
#     setuptools-42.0.2          |           py36_0         653 KB
#     mccabe-0.6.1               |           py36_1          14 KB
#     terminado-0.8.3            |           py36_0          25 KB
#     qtconsole-4.6.0            |             py_0          95 KB
#     pathtools-0.1.2            |             py_1          10 KB
#     patsy-0.5.1                |           py36_0         380 KB
#     colorama-0.4.3             |             py_0          20 KB
#     pyyaml-5.2                 |   py36h7b6447c_0         190 KB
#     snowballstemmer-2.0.0      |             py_0          58 KB
#     intervaltree-3.0.2         |             py_0          25 KB
#     pytest-openfiles-0.4.0     |             py_0          10 KB
#     nltk-3.4.5                 |           py36_0         2.1 MB
#     html5lib-1.0.1             |             py_0          89 KB
#     libgfortran-3.0.0          |                1         281 KB
#     sphinx-2.3.0               |             py_0         1.4 MB
#     curl-7.67.0                |       hbc83047_0         145 KB
#     xlsxwriter-1.2.6           |             py_0         107 KB
#     pytables-3.4.4             |   py36ha205bf6_0         1.5 MB
#     locket-0.2.0               |           py36_1           8 KB
#     secretstorage-3.1.1        |           py36_0          24 KB
#     jdcal-1.4.1                |             py_0          11 KB
#     nb_conda_kernels-2.2.2     |           py36_0          37 KB
#     krb5-1.16.4                |       h173b8e3_0         1.4 MB
#     pywavelets-1.1.1           |   py36h7b6447c_0         4.4 MB
#     xlrd-1.2.0                 |             py_0         108 KB
#     cloudpickle-1.2.2          |             py_0          29 KB
#     backports-1.0              |             py_2         139 KB
#     astroid-2.3.3              |           py36_0         291 KB
#     pygments-2.5.2             |             py_0         672 KB
#     python-language-server-0.31.2|           py36_0          72 KB
#     zict-1.0.0                 |             py_0          12 KB
#     scikit-image-0.15.0        |   py36he6710b0_0        28.4 MB
#     py-1.8.0                   |             py_0          66 KB
#     urllib3-1.25.7             |           py36_0         165 KB
#     scipy-1.3.2                |   py36h7c811a0_0        18.1 MB
#     greenlet-0.4.15            |   py36h7b6447c_0          20 KB
#     pkginfo-1.5.0.1            |           py36_0          43 KB
#     tblib-1.6.0                |             py_0          16 KB
#     pillow-6.2.1               |   py36h34e0f95_0         640 KB
#     flake8-3.7.9               |           py36_0         134 KB
#     odo-0.5.1                  |           py36_0         193 KB
#     et_xmlfile-1.0.1           |           py36_0          20 KB
#     python-jsonrpc-server-0.3.2|             py_0          13 KB
#     libtool-2.4.6              |       h7b6447c_5         513 KB
#     blaze-0.11.3               |           py36_0         603 KB
#     autopep8-1.4.4             |             py_0          41 KB
#     opencv-3.4.2               |   py36h6fd60c2_1          11 KB
#     s3fs-0.4.0                 |             py_0          24 KB
#     pathlib2-2.3.5             |           py36_0          37 KB
#     sphinxcontrib-jsmath-1.0.1 |             py_0           8 KB
#     beautifulsoup4-4.8.1       |           py36_0         153 KB
#     bleach-3.1.0               |             py_0         111 KB
#     nb_conda-2.2.1             |           py36_0          33 KB
#     lz4-c-1.8.1.2              |       h14c3975_0         158 KB
#     patchelf-0.10              |       he6710b0_0          78 KB
#     path-13.1.0                |           py36_0          35 KB
#     boto-2.49.0                |           py36_0         1.5 MB
#     mpfr-4.0.1                 |       hdf1c602_3         575 KB
#     dask-core-2.9.0            |             py_0         586 KB
#     blas-1.0                   |              mkl           6 KB
#     mpmath-1.1.0               |           py36_0         970 KB
#     parso-0.5.2                |             py_0          69 KB
#     argh-0.26.2                |           py36_0          36 KB
#     llvmlite-0.30.0            |   py36hd408876_0        17.7 MB
#     packaging-19.2             |             py_0          30 KB
#     libcurl-7.67.0             |       h20c2e04_0         576 KB
#     rope-0.14.0                |             py_0         113 KB
#     sphinxcontrib-serializinghtml-1.1.3|             py_0          24 KB
#     cytoolz-0.10.1             |   py36h7b6447c_0         437 KB
#     openpyxl-3.0.2             |             py_0         158 KB
#     blosc-1.16.3               |       hd408876_0          82 KB
#     sortedcollections-1.1.2    |           py36_0          18 KB
#     flask-1.1.1                |             py_0          73 KB
#     yapf-0.28.0                |             py_0         120 KB
#     certifi-2019.11.28         |           py36_0         156 KB
#     chardet-3.0.4              |        py36_1003         197 KB
#     pytest-5.0.1               |           py36_0         353 KB
#     ca-certificates-2019.11.27 |                0         132 KB
#     bitarray-1.2.0             |   py36h7b6447c_0          82 KB
#     click-7.0                  |             py_0          64 KB
#     itsdangerous-1.1.0         |             py_0          17 KB
#     pydocstyle-4.0.1           |             py_0          34 KB
#     jeepney-0.4.1              |             py_0          21 KB
#     wrapt-1.11.2               |   py36h7b6447c_0          48 KB
#     requests-2.22.0            |           py36_1          90 KB
#     filelock-3.0.12            |             py_0          12 KB
#     libxslt-1.1.33             |       h7d1a2b0_0         577 KB
#     bokeh-1.4.0                |           py36_0        13.6 MB
#     libvpx-1.7.0               |       h439df22_0         2.4 MB
#     pytest-astropy-header-0.1.1|             py_0          11 KB
#     numpy-1.17.4               |   py36hc1035e2_0           4 KB
#     anaconda-project-0.8.4     |             py_0         215 KB
#     numba-0.46.0               |   py36h962f231_0         3.2 MB
#     pytest-arraydiff-0.3       |   py36h39e3cac_0          15 KB
#     glob2-0.7                  |             py_0          14 KB
#     msgpack-python-0.6.1       |   py36hfd86e86_1          92 KB
#     rtree-0.8.3                |           py36_0          46 KB
#     soupsieve-1.9.5            |           py36_0          61 KB
#     libgcc-7.2.0               |       h69d50b8_2         304 KB
#     imagesize-1.1.0            |             py_0           8 KB
#     wurlitzer-2.0.0            |           py36_0          14 KB
#     freeglut-3.0.0             |       hf484d3e_5         251 KB
#     babel-2.7.0                |             py_0         5.8 MB
#     qtawesome-0.6.0            |             py_0         671 KB
#     pandas-0.25.3              |   py36he6710b0_0        11.5 MB
#     numpydoc-0.9.1             |             py_0          31 KB
#     cython-0.29.14             |   py36he6710b0_0         2.2 MB
#     atomicwrites-1.3.0         |           py36_1          13 KB
#     fastcache-1.1.0            |   py36h7b6447c_0          31 KB
#     ------------------------------------------------------------
#                                            Total:       317.0 MB
#
# The following NEW packages will be INSTALLED:
#
#     argh:                               0.26.2-py36_0
#     atomicwrites:                       1.3.0-py36_1
#     autopep8:                           1.4.4-py_0
#     diff-match-patch:                   20181111-py_0
#     flake8:                             3.7.9-py36_0
#     freeglut:                           3.0.0-hf484d3e_5
#     fsspec:                             0.6.2-py_0
#     future:                             0.18.2-py36_0
#     hypothesis:                         4.54.2-py36_0
#     importlib_metadata:                 1.3.0-py36_0
#     intervaltree:                       3.0.2-py_0
#     jeepney:                            0.4.1-py_0
#     joblib:                             0.14.1-py_0
#     json5:                              0.8.5-py_0
#     jupyterlab_server:                  1.0.6-py_0
#     keyring:                            19.2.0-py36_0
#     libglu:                             9.0.0-hf484d3e_1
#     libopencv:                          3.4.2-hb342d67_1
#     libopus:                            1.3-h7b6447c_0
#     libspatialindex:                    1.9.3-he6710b0_0
#     libvpx:                             1.7.0-h439df22_0
#     lz4-c:                              1.8.1.2-h14c3975_0
#     path:                               13.1.0-py36_0
#     pathtools:                          0.1.2-py_1
#     prometheus_client:                  0.7.1-py_0
#     py-opencv:                          3.4.2-py36hb342d67_1
#     pydocstyle:                         4.0.1-py_0
#     pympler:                            0.7-py_0
#     pyrsistent:                         0.15.6-py36h7b6447c_0
#     pytest-astropy-header:              0.1.1-py_0
#     python-jsonrpc-server:              0.3.2-py_0
#     python-language-server:             0.31.2-py36_0
#     pyxdg:                              0.26-py_0
#     qdarkstyle:                         2.7-py_0
#     rtree:                              0.8.3-py36_0
#     secretstorage:                      3.1.1-py36_0
#     soupsieve:                          1.9.5-py36_0
#     sphinxcontrib-applehelp:            1.0.1-py_0
#     sphinxcontrib-devhelp:              1.0.1-py_0
#     sphinxcontrib-htmlhelp:             1.0.2-py_0
#     sphinxcontrib-jsmath:               1.0.1-py_0
#     sphinxcontrib-qthelp:               1.0.2-py_0
#     sphinxcontrib-serializinghtml:      1.1.3-py_0
#     spyder-kernels:                     1.8.1-py36_0
#     typed-ast:                          1.4.0-py36h7b6447c_0
#     ujson:                              1.35-py36h14c3975_0
#     watchdog:                           0.9.0-py36_1
#     wurlitzer:                          2.0.0-py36_0
#     yapf:                               0.28.0-py_0
#     zipp:                               0.6.0-py_0
#     zstd:                               1.3.7-h0b5b093_0
#
# The following packages will be UPDATED:
#
#     alabaster:                          0.7.10-py36h306e16b_0                             --> 0.7.12-py_0
#     anaconda-client:                    1.6.14-py36_0                                     --> 1.7.2-py36_0
#     anaconda-project:                   0.8.2-py36h44fb852_0                              --> 0.8.4-py_0
#     asn1crypto:                         0.24.0-py36_0                                     --> 1.2.0-py36_0
#     astroid:                            1.6.3-py36_0                                      --> 2.3.3-py36_0
#     astropy:                            3.0.2-py36h3010b51_1                              --> 3.2.3-py36h7b6447c_0
#     attrs:                              18.1.0-py36_0                                     --> 19.3.0-py_0
#     babel:                              2.5.3-py36_0                                      --> 2.7.0-py_0
#     backports:                          1.0-py36hfa02d7e_1                                --> 1.0-py_2
#     backports.shutil_get_terminal_size: 1.0.0-py36hfea85ff_2                              --> 1.0.0-py36_2
#     beautifulsoup4:                     4.6.0-py36h49b8c8c_1                              --> 4.8.1-py36_0
#     bitarray:                           0.8.1-py36h14c3975_1                              --> 1.2.0-py36h7b6447c_0
#     bkcharts:                           0.2-py36h735825a_0                                --> 0.2-py36_0
#     blaze:                              0.11.3-py36h4e06776_0                             --> 0.11.3-py36_0
#     bleach:                             2.1.3-py36_0                                      --> 3.1.0-py_0
#     blosc:                              1.14.3-hdbcaa40_0                                 --> 1.16.3-hd408876_0
#     bokeh:                              1.0.4-py36_0                                      --> 1.4.0-py36_0
#     boto:                               2.48.0-py36h6e4cd66_1                             --> 2.49.0-py36_0
#     boto3:                              1.9.234-py_0                                      --> 1.10.39-py_0
#     botocore:                           1.12.234-py_0                                     --> 1.13.39-py_0
#     bottleneck:                         1.2.1-py36haac1ea0_0                              --> 1.3.1-py36hdd07704_0
#     bzip2:                              1.0.6-h14c3975_5                                  --> 1.0.8-h7b6447c_0
#     ca-certificates:                    2019.10.16-0                                      --> 2019.11.27-0
#     certifi:                            2019.9.11-py36_0                                  --> 2019.11.28-py36_0
#     cffi:                               1.11.5-py36h9745a5d_0                             --> 1.13.2-py36h2e261b9_0
#     chardet:                            3.0.4-py36h0f667ec_1                              --> 3.0.4-py36_1003
#     click:                              6.7-py36h5253387_0                                --> 7.0-py_0
#     cloudpickle:                        0.5.3-py36_0                                      --> 1.2.2-py_0
#     clyent:                             1.2.2-py36h7e57e65_1                              --> 1.2.2-py36_1
#     colorama:                           0.3.9-py36h489cec4_0                              --> 0.4.3-py_0
#     contextlib2:                        0.5.5-py36h6c84a62_0                              --> 0.6.0.post1-py_0
#     cryptography:                       2.2.2-py36h14c3975_0                              --> 2.8-py36h1ba5d50_0
#     curl:                               7.60.0-h84994c4_0                                 --> 7.67.0-hbc83047_0
#     cycler:                             0.10.0-py36h93f1223_0                             --> 0.10.0-py36_0
#     cython:                             0.28.2-py36h14c3975_0                             --> 0.29.14-py36he6710b0_0
#     cytoolz:                            0.9.0.1-py36h14c3975_0                            --> 0.10.1-py36h7b6447c_0
#     dask:                               0.17.5-py36_0                                     --> 2.9.0-py_0
#     dask-core:                          0.17.5-py36_0                                     --> 2.9.0-py_0
#     datashape:                          0.5.4-py36h3ad6b5c_0                              --> 0.5.4-py36_1
#     dbus:                               1.13.2-h714fa37_1                                 --> 1.13.12-h746ee38_0
#     decorator:                          4.3.0-py36_0                                      --> 4.4.1-py_0
#     distributed:                        1.21.8-py36_0                                     --> 2.9.0-py_0
#     docutils:                           0.14-py36hb0f60f5_0                               --> 0.15.2-py36_0
#     entrypoints:                        0.2.3-py36h1aec115_2                              --> 0.3-py36_0
#     et_xmlfile:                         1.0.1-py36hd6bccc3_0                              --> 1.0.1-py36_0
#     expat:                              2.2.5-he0dffb1_0                                  --> 2.2.6-he6710b0_0
#     fastcache:                          1.0.2-py36h14c3975_2                              --> 1.1.0-py36h7b6447c_0
#     ffmpeg:                             3.2.4-hf82bc7d_4                      conda-forge --> 4.0-hcdf2ecd_0
#     filelock:                           3.0.4-py36_0                                      --> 3.0.12-py_0
#     flask:                              1.0.2-py36_1                                      --> 1.1.1-py_0
#     flask-cors:                         3.0.4-py36_0                                      --> 3.0.8-py_0
#     gevent:                             1.3.0-py36h14c3975_0                              --> 1.4.0-py36h7b6447c_0
#     glib:                               2.56.1-h000015b_0                                 --> 2.63.1-h5a9c865_0
#     glob2:                              0.6-py36he249c77_0                                --> 0.7-py_0
#     gmpy2:                              2.0.8-py36hc8893dd_2                              --> 2.0.8-py36h10f8cd9_2
#     graphite2:                          1.3.11-h16798f4_2                                 --> 1.3.13-h23475e2_0
#     greenlet:                           0.4.13-py36h14c3975_0                             --> 0.4.15-py36h7b6447c_0
#     h5py:                               2.8.0-py36h470a237_0                  conda-forge --> 2.8.0-py36h989c5e5_3
#     harfbuzz:                           1.7.6-hec2c2bc_3                                  --> 1.8.8-hffaf4a1_0
#     hdf5:                               1.10.1-2                              conda-forge --> 1.10.2-hba1933b_1
#     heapdict:                           1.0.0-py36_2                                      --> 1.0.1-py_0
#     html5lib:                           1.0.1-py36h2f9c1c0_0                              --> 1.0.1-py_0
#     idna:                               2.6-py36h82fb2a8_1                                --> 2.8-py36_0
#     imageio:                            2.3.0-py36_0                                      --> 2.6.1-py36_0
#     imagesize:                          1.0.0-py36_0                                      --> 1.1.0-py_0
#     intel-openmp:                       2018.0.0-8                                        --> 2019.4-243
#     ipykernel:                          4.8.2-py36_0                                      --> 5.1.3-py36h39e3cac_0
#     ipython:                            6.4.0-py36_0                                      --> 7.10.2-py36h39e3cac_0
#     ipython_genutils:                   0.2.0-py36hb52b0d5_0                              --> 0.2.0-py36_0
#     ipywidgets:                         7.2.1-py36_0                                      --> 7.5.1-py_0
#     isort:                              4.3.4-py36_0                                      --> 4.3.21-py36_0
#     itsdangerous:                       0.24-py36h93cc618_1                               --> 1.1.0-py_0
#     jasper:                             1.900.1-4                             conda-forge --> 2.0.14-h07fcdf6_1
#     jdcal:                              1.4-py36_0                                        --> 1.4.1-py_0
#     jedi:                               0.12.0-py36_1                                     --> 0.14.1-py36_0
#     jinja2:                             2.10-py36ha16c418_0                               --> 2.10.3-py_0
#     jsonschema:                         2.6.0-py36h006f8b5_0                              --> 3.2.0-py36_0
#     jupyter:                            1.0.0-py36_4                                      --> 1.0.0-py36_7
#     jupyter_client:                     5.2.3-py36_0                                      --> 5.3.4-py36_0
#     jupyter_console:                    5.2.0-py36he59e554_1                              --> 6.0.0-py36_0
#     jupyter_core:                       4.4.0-py36h7c827e3_0                              --> 4.6.1-py36_0
#     jupyterlab:                         0.32.1-py36_0                                     --> 1.2.4-pyhf63ae98_0
#     jupyterlab_launcher:                0.10.5-py36_0                                     --> 0.13.1-py36_0
#     kiwisolver:                         1.0.1-py36h764f252_0                              --> 1.1.0-py36he6710b0_0
#     krb5:                               1.14.2-hcdc1b81_6                                 --> 1.16.4-h173b8e3_0
#     lazy-object-proxy:                  1.3.1-py36h10fcdad_0                              --> 1.4.3-py36h7b6447c_0
#     libcurl:                            7.60.0-h1ad7b7a_0                                 --> 7.67.0-h20c2e04_0
#     libedit:                            3.1.20170329-h6b74fdf_2                           --> 3.1.20181209-hc058e9b_0
#     libgcc:                             7.2.0-h69d50b8_2                      conda-forge --> 7.2.0-h69d50b8_2
#     libgfortran:                        3.0.0-1                               conda-forge --> 3.0.0-1
#     libgfortran-ng:                     7.2.0-hdf63c60_3                                  --> 7.3.0-hdf63c60_0
#     libopenblas:                        0.3.6-h5a2b251_1                                  --> 0.3.6-h5a2b251_2
#     libpng:                             1.6.34-hb9fc6fc_0                                 --> 1.6.37-hbc83047_0
#     libprotobuf:                        3.5.2-hd28b015_1                      conda-forge --> 3.11.2-hd408876_0
#     libssh2:                            1.8.0-h9cfc8f7_4                                  --> 1.8.2-h1ba5d50_0
#     libtiff:                            4.0.9-he85c1e1_1                                  --> 4.1.0-h2733197_0
#     libtool:                            2.4.6-h544aabb_3                                  --> 2.4.6-h7b6447c_5
#     libwebp:                            0.5.2-7                               conda-forge --> 1.0.1-h8e7db2f_0
#     libxml2:                            2.9.8-h26e45fe_1                                  --> 2.9.9-hea5a465_1
#     libxslt:                            1.1.32-h1312cb7_0                                 --> 1.1.33-h7d1a2b0_0
#     llvmlite:                           0.23.1-py36hdbcaa40_0                             --> 0.30.0-py36hd408876_0
#     locket:                             0.2.0-py36h787c0ad_1                              --> 0.2.0-py36_1
#     lxml:                               4.2.1-py36h23eabaa_0                              --> 4.4.2-py36hefd8a0e_0
#     markupsafe:                         1.0-py36hd9260cd_1                                --> 1.1.1-py36h7b6447c_0
#     matplotlib:                         2.2.2-py36hb69df0a_2                              --> 3.1.1-py36h5429711_0
#     mccabe:                             0.6.1-py36h5ad9710_1                              --> 0.6.1-py36_1
#     mistune:                            0.8.3-py36h14c3975_1                              --> 0.8.4-py36h7b6447c_0
#     mkl:                                2018.0.2-1                                        --> 2019.4-243
#     mkl-service:                        1.1.2-py36h17a0993_4                              --> 2.3.0-py36he904b0f_0
#     mkl_fft:                            1.0.10-py36_0                         conda-forge --> 1.0.15-py36ha843d7b_0
#     mkl_random:                         1.0.2-py36_0                          conda-forge --> 1.1.0-py36hd6b4f25_0
#     more-itertools:                     4.1.0-py36_0                                      --> 8.0.2-py_0
#     mpc:                                1.0.3-hec55b23_5                                  --> 1.1.0-h10f8cd9_1
#     mpfr:                               3.1.5-h11a74b3_2                                  --> 4.0.1-hdf1c602_3
#     mpi:                                1.0-openmpi                           conda-forge --> 1.0-openmpi
#     mpmath:                             1.0.0-py36hfeacd6b_2                              --> 1.1.0-py36_0
#     msgpack-python:                     0.5.6-py36h6bb024c_0                              --> 0.6.1-py36hfd86e86_1
#     multipledispatch:                   0.5.0-py36_0                                      --> 0.6.0-py36_0
#     nb_conda_kernels:                   2.2.2-py36_0                          conda-forge --> 2.2.2-py36_0
#     nbconvert:                          5.4.1-py36_3                                      --> 5.6.1-py36_0
#     nbformat:                           4.4.0-py36h31c9010_0                              --> 4.4.0-py36_0
#     ncurses:                            6.1-hf484d3e_0                                    --> 6.1-he6710b0_1
#     networkx:                           2.1-py36_0                                        --> 2.4-py_0
#     nltk:                               3.3.0-py36_0                                      --> 3.4.5-py36_0
#     nose:                               1.3.7-py36hcdf7029_2                              --> 1.3.7-py36_2
#     notebook:                           5.5.0-py36_0                                      --> 6.0.2-py36_0
#     numba:                              0.38.0-py36h637b7d7_0                             --> 0.46.0-py36h962f231_0
#     numexpr:                            2.7.0-py36hb3f55d8_0                  conda-forge --> 2.7.0-py36h9e4a6bb_0
#     numpy:                              1.15.2-py36_blas_openblashd3ea46f_1   conda-forge [blas_openblas] --> 1.17.4-py36hc1035e2_0
#     numpy-base:                         1.17.2-py36h2f8d375_0                             --> 1.17.4-py36hde5b4d6_0
#     numpydoc:                           0.8.0-py36_0                                      --> 0.9.1-py_0
#     odo:                                0.5.1-py36h90ed295_0                              --> 0.5.1-py36_0
#     olefile:                            0.45.1-py36_0                                     --> 0.46-py_0
#     opencv:                             3.3.0-py36_blas_openblas_204          conda-forge [blas_openblas] --> 3.4.2-py36h6fd60c2_1
#     openmpi:                            3.1.0-h26a2512_3                      conda-forge --> 4.0.2-hb1b8bf9_1
#     openpyxl:                           2.5.3-py36_0                                      --> 3.0.2-py_0
#     openssl:                            1.0.2t-h7b6447c_1                                 --> 1.1.1d-h7b6447c_3
#     packaging:                          17.1-py36_0                                       --> 19.2-py_0
#     pandas:                             0.24.2-py36he6710b0_0                             --> 0.25.3-py36he6710b0_0
#     pandoc:                             1.19.2.1-hea2e7c5_1                               --> 2.2.3.2-0
#     pandocfilters:                      1.4.2-py36ha6701b7_1                              --> 1.4.2-py36_1
#     pango:                              1.42.3-h8589676_0                                 --> 1.42.4-h049681c_0
#     parso:                              0.2.0-py36_0                                      --> 0.5.2-py_0
#     partd:                              0.3.8-py36h36fd896_0                              --> 1.1.0-py_0
#     patchelf:                           0.9-hf79760b_2                                    --> 0.10-he6710b0_0
#     path.py:                            11.0.1-py36_0                                     --> 12.4.0-0
#     pathlib2:                           2.3.2-py36_0                                      --> 2.3.5-py36_0
#     patsy:                              0.5.0-py36_0                                      --> 0.5.1-py36_0
#     pcre:                               8.42-h439df22_0                                   --> 8.43-he6710b0_0
#     pexpect:                            4.5.0-py36_0                                      --> 4.7.0-py36_0
#     pickleshare:                        0.7.4-py36h63277f8_0                              --> 0.7.5-py36_0
#     pillow:                             5.2.0-py36heded4f4_0                              --> 6.2.1-py36h34e0f95_0
#     pip:                                10.0.1-py36_0                                     --> 19.3.1-py36_0
#     pixman:                             0.34.0-hceecf20_3                                 --> 0.38.0-h7b6447c_0
#     pkginfo:                            1.4.2-py36_1                                      --> 1.5.0.1-py36_0
#     pluggy:                             0.6.0-py36hb689045_0                              --> 0.13.1-py36_0
#     prompt_toolkit:                     1.0.15-py36h17d85b1_0                             --> 2.0.10-py_0
#     protobuf:                           3.5.2-py36hd28b015_0                  conda-forge --> 3.11.2-py36he6710b0_0
#     psutil:                             5.6.3-py36h7b6447c_0                              --> 5.6.7-py36h7b6447c_0
#     ptyprocess:                         0.5.2-py36h69acd42_0                              --> 0.6.0-py36_0
#     py:                                 1.5.3-py36_0                                      --> 1.8.0-py_0
#     pycodestyle:                        2.4.0-py36_0                                      --> 2.5.0-py36_0
#     pycosat:                            0.6.3-py36h0a5515d_0                              --> 0.6.3-py36h14c3975_0
#     pycparser:                          2.18-py36hf9f622e_1                               --> 2.19-py_0
#     pycrypto:                           2.6.1-py36h14c3975_8                              --> 2.6.1-py36h14c3975_9
#     pycurl:                             7.43.0.1-py36hb7f436b_0                           --> 7.43.0.3-py36h1ba5d50_0
#     pyflakes:                           1.6.0-py36h7bd6a15_0                              --> 2.1.1-py36_0
#     pygments:                           2.2.0-py36h0d3125c_0                              --> 2.5.2-py_0
#     pylint:                             1.8.4-py36_0                                      --> 2.4.4-py36_0
#     pyodbc:                             4.0.23-py36hf484d3e_0                             --> 4.0.27-py36he6710b0_0
#     pyopenssl:                          18.0.0-py36_0                                     --> 19.1.0-py36_0
#     pyparsing:                          2.2.0-py36hee85983_1                              --> 2.4.5-py_0
#     pyqt:                               5.6.0-py36_2                                      --> 5.9.2-py36h05f1152_2
#     pysocks:                            1.6.8-py36_0                                      --> 1.7.1-py36_0
#     pytest:                             3.5.1-py36_0                                      --> 5.0.1-py36_0
#     pytest-arraydiff:                   0.2-py36_0                                        --> 0.3-py36h39e3cac_0
#     pytest-astropy:                     0.3.0-py36_0                                      --> 0.7.0-py_0
#     pytest-doctestplus:                 0.1.3-py36_0                                      --> 0.5.0-py_0
#     pytest-openfiles:                   0.3.0-py36_0                                      --> 0.4.0-py_0
#     pytest-remotedata:                  0.2.1-py36_0                                      --> 0.3.2-py36_0
#     python:                             3.6.5-hc3d631a_2                                  --> 3.6.9-h265db76_0
#     python-dateutil:                    2.7.3-py36_0                                      --> 2.8.0-py36_0
#     pytz:                               2018.4-py36_0                                     --> 2019.3-py_0
#     pywavelets:                         0.5.2-py36he602eb0_0                              --> 1.1.1-py36h7b6447c_0
#     pyyaml:                             3.12-py36hafb9ca4_1                               --> 5.2-py36h7b6447c_0
#     pyzmq:                              17.0.0-py36h14c3975_0                             --> 18.1.0-py36he6710b0_0
#     qt:                                 5.6.3-h39df351_1                                  --> 5.9.7-h5867ecd_1
#     qtawesome:                          0.4.4-py36h609ed8c_0                              --> 0.6.0-py_0
#     qtconsole:                          4.3.1-py36h8f73b5b_0                              --> 4.6.0-py_0
#     qtpy:                               1.4.1-py36_0                                      --> 1.9.0-py_0
#     readline:                           7.0-ha6073c6_4                                    --> 7.0-h7b6447c_5
#     requests:                           2.20.0-py36_1000                      conda-forge --> 2.22.0-py36_1
#     rope:                               0.10.7-py36h147e2ec_0                             --> 0.14.0-py_0
#     ruamel_yaml:                        0.15.35-py36h14c3975_1                            --> 0.15.46-py36h14c3975_0
#     s3fs:                               0.1.5-py36_0                                      --> 0.4.0-py_0
#     scikit-image:                       0.13.1-py36h14c3975_1                             --> 0.15.0-py36he6710b0_0
#     scikit-learn:                       0.20.0-py36_blas_openblasha84fab4_201 conda-forge [blas_openblas] --> 0.22-py36hd81dba3_0
#     scipy:                              1.1.0-py36_blas_openblash7943236_201  conda-forge [blas_openblas] --> 1.3.2-py36h7c811a0_0
#     seaborn:                            0.8.1-py36hfad7ec4_0                              --> 0.9.0-pyh91ea838_1
#     setuptools:                         39.1.0-py36_0                                     --> 42.0.2-py36_0
#     singledispatch:                     3.4.0.3-py36h7a266c3_0                            --> 3.4.0.3-py36_0
#     six:                                1.11.0-py36h372c433_1                             --> 1.13.0-py36_0
#     snowballstemmer:                    1.2.1-py36h6febd40_0                              --> 2.0.0-py_0
#     sortedcollections:                  0.6.1-py36_0                                      --> 1.1.2-py36_0
#     sortedcontainers:                   1.5.10-py36_0                                     --> 2.1.0-py36_0
#     sphinx:                             1.7.4-py36_0                                      --> 2.3.0-py_0
#     sphinxcontrib:                      1.0-py36h6d0f590_1                                --> 1.0-py36_1
#     sphinxcontrib-websupport:           1.0.1-py36hb5cb234_1                              --> 1.1.2-py_0
#     spyder:                             3.2.8-py36_0                                      --> 4.0.0-py36_0
#     sqlalchemy:                         1.2.7-py36h6b74fdf_0                              --> 1.3.11-py36h7b6447c_0
#     sqlite:                             3.28.0-h8b20d00_0                     conda-forge --> 3.30.1-h7b6447c_0
#     statsmodels:                        0.9.0-py36h3010b51_0                              --> 0.10.1-py36hdd07704_0
#     sympy:                              1.1.1-py36hc6d1c1c_0                              --> 1.5-py36_0
#     tblib:                              1.3.2-py36h34cf8b6_0                              --> 1.6.0-py_0
#     terminado:                          0.8.1-py36_1                                      --> 0.8.3-py36_0
#     testpath:                           0.3.1-py36h8cadb63_0                              --> 0.4.4-py_0
#     tk:                                 8.6.7-hc745277_3                                  --> 8.6.8-hbc83047_0
#     toolz:                              0.9.0-py36_0                                      --> 0.10.0-py_0
#     tornado:                            5.0.2-py36_0                                      --> 6.0.3-py36h7b6447c_0
#     traitlets:                          4.3.2-py36h674d592_0                              --> 4.3.3-py36_0
#     unicodecsv:                         0.14.1-py36ha668878_0                             --> 0.14.1-py36_0
#     unixodbc:                           2.3.6-h1bed415_0                                  --> 2.3.7-h14c3975_0
#     urllib3:                            1.22-py36hbe7ace6_0                               --> 1.25.7-py36_0
#     wcwidth:                            0.1.7-py36hdf4376a_0                              --> 0.1.7-py36_0
#     webencodings:                       0.5.1-py36h800622e_1                              --> 0.5.1-py36_1
#     werkzeug:                           0.14.1-py36_0                                     --> 0.16.0-py_0
#     wheel:                              0.31.1-py36_0                                     --> 0.33.6-py36_0
#     widgetsnbextension:                 3.2.1-py36_0                                      --> 3.5.1-py36_0
#     wrapt:                              1.10.11-py36h28b7045_0                            --> 1.11.2-py36h7b6447c_0
#     xlrd:                               1.1.0-py36h1db9f0c_1                              --> 1.2.0-py_0
#     xlsxwriter:                         1.0.4-py36_0                                      --> 1.2.6-py_0
#     xlwt:                               1.3.0-py36h7b00a1f_0                              --> 1.3.0-py36_0
#     zeromq:                             4.2.5-h439df22_0                                  --> 4.3.1-he6710b0_3
#     zict:                               0.1.3-py36h3a3bf81_0                              --> 1.0.0-py_0
#     zlib:                               1.2.11-ha838bed_2                                 --> 1.2.11-h7b6447c_3
#
# The following packages will be DOWNGRADED:
#
# ...
#      |████████████████████████████████| 501kB 38.6MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from tensorflow==2.0.0-beta1) (3.11.2)
# Collecting absl-py>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/1a/53/9243c600e047bd4c3df9e69cfabc1e8004a82cac2e0c484580a78a94ba2a/absl-py-0.9.0.tar.gz (104kB)
#      |████████████████████████████████| 112kB 38.4MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from tensorflow==2.0.0-beta1) (1.11.2)
# Requirement already satisfied, skipping upgrade: h5py in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from keras-applications>=1.0.6->tensorflow==2.0.0-beta1) (2.8.0)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow==2.0.0-beta1) (0.16.0)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow==2.0.0-beta1) (42.0.2.post20191203)
# Collecting markdown>=2.6.8
#   Downloading https://files.pythonhosted.org/packages/c0/4e/fd492e91abdc2d2fcb70ef453064d980688762079397f779758e055f6575/Markdown-3.1.1-py2.py3-none-any.whl (87kB)
#      |████████████████████████████████| 92kB 16.0MB/s eta 0:00:01
# Building wheels for collected packages: termcolor, gast, absl-py
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-cp36-none-any.whl size=4832 sha256=de19aff9be0f05b4f19c1592a309c08c672758455883c4b1894f3f9b2b409f72
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/7c/06/54/bc84598ba1daf8f970247f550b175aaaee85f68b4b0c5ab2c6
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.3.2-cp36-none-any.whl size=9679 sha256=ec68c28247cb6de402ccc0504b47f3593e4254d640c4604a91a7e73b1a76fada
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/59/38/c6/234dc39b4f6951a0768fbc02d5b7207137a5b1d9094f0d54bf
#   Building wheel for absl-py (setup.py) ... done
#   Created wheel for absl-py: filename=absl_py-0.9.0-cp36-none-any.whl size=121931 sha256=87b793a5aae93983b75402fe81549b3bb765f186900290ae112ae561038bb348
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/8e/28/49/fad4e7f0b9a1227708cbbee4487ac8558a7334849cb81c813d
# Successfully built termcolor gast absl-py
# Installing collected packages: astor, termcolor, grpcio, keras-applications, gast, keras-preprocessing, markdown, absl-py, tb-nightly, google-pasta, tf-estimator-nightly, tensorflow
# Successfully installed absl-py-0.9.0 astor-0.8.1 gast-0.3.2 google-pasta-0.1.8 grpcio-1.26.0 keras-applications-1.0.8 keras-preprocessing-1.1.0 markdown-3.1.1 tb-nightly-1.14.0a20190603 tensorflow-2.0.0b1 termcolor-1.1.0 tf-estimator-nightly-1.14.0.dev2019060501
# Collecting turicreate
#   Downloading https://files.pythonhosted.org/packages/48/21/ab91268cac757636b6b906913121e99824d63c47a037fbadd33dcb460efc/turicreate-6.0-cp36-cp36m-manylinux1_x86_64.whl (91.2MB)
#      |████████████████████████████████| 91.2MB 34kB/s s eta 0:00:01     |██████████████▊                 | 42.1MB 15.9MB/s eta 0:00:04
# Collecting resampy==0.2.1
#   Downloading https://files.pythonhosted.org/packages/14/b6/66a06d85474190b50aee1a6c09cdc95bb405ac47338b27e9b21409da1760/resampy-0.2.1.tar.gz (322kB)
#      |████████████████████████████████| 327kB 44.1MB/s eta 0:00:01
# Collecting coremltools==3.1
#   Downloading https://files.pythonhosted.org/packages/af/f8/ac6940600864b08476fee09583b7c66e2fcfe70ccafeb696710103c4a31b/coremltools-3.1-cp36-none-manylinux1_x86_64.whl (3.4MB)
#      |████████████████████████████████| 3.4MB 42.1MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: pandas>=0.23.2 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from turicreate) (0.25.3)
# Requirement already satisfied, skipping upgrade: requests>=2.9.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from turicreate) (2.22.0)
# Collecting prettytable==0.7.2
#   Downloading https://files.pythonhosted.org/packages/ef/30/4b0746848746ed5941f052479e7c23d2b56d174b82f4fd34a25e389831f5/prettytable-0.7.2.tar.bz2
# Requirement already satisfied, skipping upgrade: scipy>=1.1.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from turicreate) (1.3.2)
# Requirement already satisfied, skipping upgrade: pillow>=5.2.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from turicreate) (6.2.1)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from turicreate) (1.13.0)
# Collecting tensorflow>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/46/0f/7bd55361168bb32796b360ad15a25de6966c9c1beb58a8e30c01c8279862/tensorflow-2.0.0-cp36-cp36m-manylinux2010_x86_64.whl (86.3MB)
#      |████████████████████████████████| 86.3MB 51kB/s s eta 0:00:01
# Requirement already satisfied, skipping upgrade: decorator>=4.0.9 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from turicreate) (4.4.1)
# Collecting numpy==1.16.4
#   Downloading https://files.pythonhosted.org/packages/87/2d/e4656149cbadd3a8a0369fcd1a9c7d61cc7b87b3903b85389c70c989a696/numpy-1.16.4-cp36-cp36m-manylinux1_x86_64.whl (17.3MB)
#      |████████████████████████████████| 17.3MB 137kB/s  eta 0:00:01
# Requirement already satisfied, skipping upgrade: numba>=0.32 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from resampy==0.2.1->turicreate) (0.46.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.1.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from coremltools==3.1->turicreate) (3.11.2)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from pandas>=0.23.2->turicreate) (2.8.0)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from pandas>=0.23.2->turicreate) (2019.3)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests>=2.9.1->turicreate) (1.25.7)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests>=2.9.1->turicreate) (2019.11.28)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests>=2.9.1->turicreate) (2.8)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests>=2.9.1->turicreate) (3.0.4)
# Collecting tensorboard<2.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/76/54/99b9d5d52d5cb732f099baaaf7740403e83fe6b0cedde940fabd2b13d75a/tensorboard-2.0.2-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 39.6MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from tensorflow>=2.0.0->turicreate) (1.1.0)
# Requirement already satisfied, skipping upgrade: astor>=0.6.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from tensorflow>=2.0.0->turicreate) (0.8.1)
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from tensorflow>=2.0.0->turicreate) (1.26.0)
# Collecting tensorflow-estimator<2.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/fc/08/8b927337b7019c374719145d1dceba21a8bb909b93b1ad6f8fb7d22c1ca1/tensorflow_estimator-2.0.1-py2.py3-none-any.whl (449kB)
#      |████████████████████████████████| 450kB 46.3MB/s eta 0:00:01
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Collecting opt-einsum>=2.3.2
#   Downloading https://files.pythonhosted.org/packages/b8/83/755bd5324777875e9dff19c2e59daec837d0378c09196634524a3d7269ac/opt_einsum-3.1.0.tar.gz (69kB)
#      |████████████████████████████████| 71kB 1.2MB/s  eta 0:00:01
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from tensorflow>=2.0.0->turicreate) (1.1.0)
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.6 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from tensorflow>=2.0.0->turicreate) (0.1.8)
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from tensorflow>=2.0.0->turicreate) (1.11.2)
# Requirement already satisfied, skipping upgrade: wheel>=0.26 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from tensorflow>=2.0.0->turicreate) (0.33.6)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.8 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from tensorflow>=2.0.0->turicreate) (1.0.8)
# Requirement already satisfied, skipping upgrade: absl-py>=0.7.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from tensorflow>=2.0.0->turicreate) (0.9.0)
# Requirement already satisfied, skipping upgrade: llvmlite>=0.30.0dev0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from numba>=0.32->resampy==0.2.1->turicreate) (0.30.0)
# Requirement already satisfied, skipping upgrade: setuptools in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from protobuf>=3.1.0->coremltools==3.1->turicreate) (42.0.2.post20191203)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow>=2.0.0->turicreate) (3.1.1)
# Collecting google-auth<2,>=1.6.3
#   Downloading https://files.pythonhosted.org/packages/36/f8/84b5771faec3eba9fe0c91c8c5896364a8ba08852c0dea5ad2025026dd95/google_auth-1.10.0-py2.py3-none-any.whl (76kB)
#      |████████████████████████████████| 81kB 15.5MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow>=2.0.0->turicreate) (0.16.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading https://files.pythonhosted.org/packages/7b/b8/88def36e74bee9fce511c9519571f4e485e890093ab7442284f4ffaef60b/google_auth_oauthlib-0.4.1-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: h5py in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from keras-applications>=1.0.8->tensorflow>=2.0.0->turicreate) (2.8.0)
# Collecting pyasn1-modules>=0.2.1
#   Downloading https://files.pythonhosted.org/packages/52/50/bb4cefca37da63a0c52218ba2cb1b1c36110d84dcbae8aa48cd67c5e95c2/pyasn1_modules-0.2.7-py2.py3-none-any.whl (131kB)
#      |████████████████████████████████| 133kB 54.1MB/s eta 0:00:01
# Collecting cachetools<5.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/08/6a/abf83cb951617793fd49c98cb9456860f5df66ff89883c8660aa0672d425/cachetools-4.0.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: rsa<4.1,>=3.1.4 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow>=2.0.0->turicreate) (3.4.2)
# Collecting requests-oauthlib>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/a3/12/b92740d845ab62ea4edf04d2f4164d82532b5a0b03836d4d4e71c6f3d379/requests_oauthlib-1.3.0-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow>=2.0.0->turicreate) (0.4.8)
# Collecting oauthlib>=3.0.0
#   Downloading https://files.pythonhosted.org/packages/05/57/ce2e7a8fa7c0afb54a0581b14a65b56e62b5759dbc98e80627142b8a3704/oauthlib-3.1.0-py2.py3-none-any.whl (147kB)
#      |████████████████████████████████| 153kB 52.8MB/s eta 0:00:01
# Building wheels for collected packages: resampy, prettytable, gast, opt-einsum
#   Building wheel for resampy (setup.py) ... done
#   Created wheel for resampy: filename=resampy-0.2.1-cp36-none-any.whl size=320847 sha256=4ceb207b796f359490599c1f07b01ce4fdcd253ae235b8af6c1ae4ca086cb352
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/ff/4f/ed/2e6c676c23efe5394bb40ade50662e90eb46e29b48324c5f9b
#   Building wheel for prettytable (setup.py) ... done
#   Created wheel for prettytable: filename=prettytable-0.7.2-cp36-none-any.whl size=13700 sha256=d70e923b4447120f0af5183b7dfc308c826e18d9f2114cfb01dd316232a106ee
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/80/34/1c/3967380d9676d162cb59513bd9dc862d0584e045a162095606
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=926058f646195c5057e251c7340b9560c14f42e196fdc64e56a9b63d0abb64d7
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
#   Building wheel for opt-einsum (setup.py) ... done
#   Created wheel for opt-einsum: filename=opt_einsum-3.1.0-cp36-none-any.whl size=61682 sha256=8e7939ef3e47a5e7d86bb2620f4dd67ae322c66a42db851aaacfbcee44839d5f
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/2c/b1/94/43d03e130b929aae7ba3f8d15cbd7bc0d1cb5bb38a5c721833
# Successfully built resampy prettytable gast opt-einsum
# ERROR: sparkmagic 0.12.5 has requirement ipykernel<5,>=4.2.2, but you'll have ipykernel 5.1.3 which is incompatible.
# ERROR: sparkmagic 0.12.5 has requirement ipython<7,>=4.0.2, but you'll have ipython 7.10.2 which is incompatible.
# ERROR: sparkmagic 0.12.5 has requirement notebook<6.0,>=4.2, but you'll have notebook 6.0.2 which is incompatible.
# ERROR: sagemaker 1.45.0.dev0 has requirement requests<2.21,>=2.20.0, but you'll have requests 2.22.0 which is incompatible.
# ERROR: amazonei-mxnet 1.4.1 has requirement numpy<1.15.0,>=1.8.2, but you'll have numpy 1.16.4 which is incompatible.
# Installing collected packages: numpy, resampy, coremltools, prettytable, pyasn1-modules, cachetools, google-auth, oauthlib, requests-oauthlib, google-auth-oauthlib, tensorboard, tensorflow-estimator, gast, opt-einsum, tensorflow, turicreate
#   Found existing installation: numpy 1.17.4
#     Uninstalling numpy-1.17.4:
#       Successfully uninstalled numpy-1.17.4
#   Found existing installation: gast 0.3.2
#     Uninstalling gast-0.3.2:
#       Successfully uninstalled gast-0.3.2
#   Found existing installation: tensorflow 2.0.0b1
#     Uninstalling tensorflow-2.0.0b1:
#       Successfully uninstalled tensorflow-2.0.0b1
# Successfully installed cachetools-4.0.0 coremltools-3.1 gast-0.2.2 google-auth-1.10.0 google-auth-oauthlib-0.4.1 numpy-1.16.4 oauthlib-3.1.0 opt-einsum-3.1.0 prettytable-0.7.2 pyasn1-modules-0.2.7 requests-oauthlib-1.3.0 resampy-0.2.1 tensorboard-2.0.2 tensorflow-2.0.0 tensorflow-estimator-2.0.1 turicreate-6.0

# %% [markdown]
# ## Prep benchmarks

# %%
import turicreate
import numpy as np
import warnings
import datetime as dt
import time
import gc

warnings.filterwarnings("ignore")

benchmarks = {}

def benchmark(f, name, df, repetitions=1, **kwargs):
    times = []
    count = 0
    for i in range(repetitions):
        start_time = time.time()
        ret = f(df, **kwargs)
        times.append(time.time()-start_time)
        count+=1
    benchmarks[name] = np.mean(times)/count
    return benchmarks[name]

def get_results(benchmarks, name):
    results = pd.DataFrame.from_dict(benchmarks, orient='index')
    results.columns = [name]
    return results

# %% [markdown]
# ### Turicreate implementation

# %%
def read_file():
    return tc.SFrame('../datasets/taxi_1m.sframe')
    
def mean(df):
    return df['fare_amount'].mean()
    
def standard_deviation(df):
    return df['fare_amount'].std()

def sum_columns(df):
    return df['fare_amount'] + df['passenger_count']

def product_columns(df):
    return df['fare_amount'] * df['passenger_count']

def complicated_arithmetic_operation(df):
    theta_1 = df['pickup_longitude']
    phi_1 = df['pickup_latitude']
    theta_2 = df['dropoff_longitude']
    phi_2 = df['dropoff_latitude']
    temp = (np.sin((theta_2-theta_1)/2*np.pi/180)**2
           + np.cos(theta_1*np.pi/180)*np.cos(theta_2*np.pi/180) * np.sin((phi_2-phi_1)/2*np.pi/180)**2)
    return 2 * np.arctan2(np.sqrt(temp), np.sqrt(1-temp))

def value_counts(df):
    return df['passenger_count'].value_counts()

def groupby_statistics(df):
    return df.groupby(key_column_names = 'pickup_hour', 
           operations = {
               'fare_amount_mean':tc.aggregate.MEAN('fare_amount'),
               'fare_amount_std':tc.aggregate.STD('fare_amount'),
               'tip_amount_mean':tc.aggregate.MEAN('tip_amount'),
               'tip_amount_mean':tc.aggregate.STD('tip_amount')
           })

def join(df, other):
    df_joined = df.join(gp, on = 'pickup_hour')
    

def filter_data(df):
    return df[expr_filter]


def skeatch_mean(df):
    return tc.Sketch(df['fare_amount']).mean()
    
def skeatch_standatd_deviation(df):
    return tc.Sketch(df['fare_amount']).std()

def skeatch_frequent_items(df):
    return tc.Sketch(df['passenger_count']).frequent_items()

# %% [markdown]
# ## Naive

# %%
# Load data
import pandas as pd
data = tc.SFrame('../datasets/taxi_1m.sframe')
data['pickup_hour'] = df['pickup_datetime'].str_to_datetime().apply(lambda x: x.hour)

# %%
# benchmark
benchmark(mean, 'mean', data, repetitions=10)
benchmark(standard_deviation,'standard deviation', data, repetitions=10)
benchmark(sum_columns, 'sum columns', data, repetitions=10)
benchmark(product_columns, 'product columns', data, repetitions=10)
benchmark(complicated_arithmetic_operation, 'complicated arithmetic operation', data, repetitions=10)
benchmark(value_counts, 'value counts', data, repetitions=10)
benchmark(groupby_statistics, 'groupby statistics', data, repetitions=10)

# Sketch
benchmark(skeatch_mean, 'sketch mean', data, repetitions=10)
benchmark(skeatch_standatd_deviation,'sketch standard deviation', data, repetitions=10)
benchmark(skeatch_frequent_items,'skeatch frequent items', data, repetitions=10)

gp = groupby_statistics(data)

benchmark(join, 'join', data, repetitions=10, other=gp)
print(f"Done benchmarks on all data")
# Out:
# Done benchmarks on all data

# %% [markdown]
# ## Filtered

# %%
# load data
long_min = -74.05
long_max = -73.75
lat_min = 40.58
lat_max = 40.90

expr_filter = (df['pickup_longitude'] > long_min)  & (df['pickup_longitude'] < long_max) & \
              (df['pickup_latitude'] > lat_min)    & (df['pickup_latitude'] < lat_max) & \
              (df['dropoff_longitude'] > long_min) & (df['dropoff_longitude'] < long_max) & \
              (df['dropoff_latitude'] > lat_min)   & (df['dropoff_latitude'] < lat_max)

filterd = data[expr_filter]
del data
del gp

deleted = gc.collect()
print(f"Prepare filtered data and deleted {deleted} MB")
# Out:
# Prepare filtered data and deleted 1877 MB

# %%
# benchmark
benchmark(mean, 'filtered mean', filterd, repetitions=10)
benchmark(standard_deviation,'filtered standard deviation', filterd, repetitions=10)
benchmark(sum_columns, 'filtered sum columns', filterd, repetitions=10)
benchmark(product_columns, 'filtered product_columns', filterd, repetitions=10)
benchmark(complicated_arithmetic_operation, 'filtered complicated arithmetic_operation', filterd, repetitions=10)
benchmark(value_counts, 'filtered value_counts', filterd, repetitions=10)
benchmark(groupby_statistics, 'filtered groupby statistics', filterd, repetitions=10)

# Sketch
benchmark(skeatch_mean, 'filtered sketch mean', filterd, repetitions=10)
benchmark(skeatch_standatd_deviation,'filtered sketch standard deviation', filterd, repetitions=10)
benchmark(skeatch_frequent_items,'filtered skeatch frequent items', filterd, repetitions=10)

gp = groupby_statistics(filterd)
benchmark(join, 'filtered join', filterd, repetitions=10, other=gp)
# Out:
# 0.61381427526474

# %%
name = 'turicreate'
results = get_results(benchmarks, name)
results.to_csv(f"../results/{name}_1m.csv")
results.head()
# Out:
#                                   turicreate
# mean                                0.004361
# standard deviation                  0.004402
# sum columns                         0.000021
# product columns                     0.000020
# complicated arithmetic operation    0.243160
